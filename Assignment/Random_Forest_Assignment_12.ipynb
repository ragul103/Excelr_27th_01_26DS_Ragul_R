# %% [markdown]
# ## Random Forset Assignment_12

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load a Dataset
df=pd.read_excel('glass.xlsx',sheet_name='glass')
#display top 5 data
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %% [markdown]
# ### 1. Exploratory Data Analysis (EDA):
#
# #### Perform exploratory data analysis to understand the structure of the dataset.

# %%
#shape
df.shape
# Out:
# (214, 10)

# %%
#information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %% [markdown]
# #### Check for missing values, outliers, inconsistencies in the data.

# %%
#check missing values
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
#stastical data
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
#Outlier Detection
plt.figure(figsize=(12,6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# The boxplot shows that K, Ca, and Ba have noticeable outliers, while RI and Si are stable with minimal variation. Since Random Forest is robust to outliers, they are not removed.

# %% [markdown]
# ### 2: Data Visualization:
#
# #### Create visualizations such as histograms, box plots, or pair plots to visualize the distributions and relationships between features.

# %%
# Histogram
df.hist(figsize=(12,10))
plt.show()

# %% [raw]
# Histograms show that most features are normally distributed, while K, Ba, and Fe are skewed with values concentrated near zero.

# %%
#Pairplot
sns.pairplot(df, hue='Type')
plt.show()

# %% [raw]
# The pairplot visualizes relationships between features and class distribution. Some clusters are visible, but there is overlap between classes, indicating that the dataset is not perfectly separable.

# %% [markdown]
# #### Analyze any patterns or correlations observed in the data.

# %%
#corr
corr=df.corr(numeric_only=True)
corr
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# Na   -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg   -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# Al   -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si   -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K    -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca    0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba   -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe    0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
# Type -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054  0.000952
#
#             Ba        Fe      Type
# RI   -0.000386  0.143010 -0.164237
# Na    0.326603 -0.241346  0.502898
# Mg   -0.492262  0.083060 -0.744993
# ...

# %%
# Correlation heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %% [raw]
# The correlation analysis shows that RI and Ca are strongly positively correlated, while Mg has a strong negative correlation with Type. Features like Al and Ba show moderate positive correlation with Type, indicating their importance in classification.

# %% [markdown]
# ### 3: Data Preprocessing
#
# #### 1. Check for missing values in the dataset and decide on a strategy for handling them.Implement the chosen strategy (e.g., imputation or removal) and explain your reasoning.

# %%
#Check missing values
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %% [raw]
# No missing values → No imputation required

# %% [markdown]
# #### 2. If there are categorical variables, apply encoding techniques like one-hot encoding to convert them into numerical format.

# %%
df.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %% [markdown]
# No categorical features → Encoding not required

# %% [markdown]
# #### 3. Apply feature scaling techniques such as standardization or normalization to ensure that all features are on a similar scale. Handling the imbalance data.

# %%
from sklearn.preprocessing import StandardScaler

X = df.drop("Type", axis=1)
y = df["Type"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

# %% [raw]
# Dataset is imbalanced (some classes have fewer samples)
# SMOTE creates synthetic samples → balances data

# %% [markdown]
# ### 4: Random Forest Model Implementation
# #### 1. Divide the data into train and test split.

# %%
#split train and Test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %% [markdown]
# #### 2. Implement a Random Forest classifier using Python and a machine learning library like scikit-learn.

# %%
#Model Implementation
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### 3. Train the model on the train dataset. Evaluate the performance on test data using metrics like accuracy, precision, recall, and F1-score.

# %%
#Prediction & Evaluation
from sklearn.metrics import accuracy_score, classification_report

y_pred = rf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))  #testing data
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9239130434782609
#               precision    recall  f1-score   support
#
#            1       0.87      0.76      0.81        17
#            2       0.85      0.89      0.87        19
#            3       0.83      1.00      0.91        10
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00        14
#            7       1.00      0.94      0.97        18
#
#     accuracy                           0.92        92
#    macro avg       0.93      0.93      0.93        92
# weighted avg       0.93      0.92      0.92        92

# %% [raw]
# The Random Forest model achieved 92% accuracy with good precision, recall, and F1-score, indicating strong performance.

# %% [markdown]
# ### 5: Bagging and Boosting Methods
# #### Apply the Bagging and Boosting methods and compare the results.

# %%
#Bagging 
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

bagging = BaggingClassifier(estimator=DecisionTreeClassifier(),n_estimators=100,random_state=42)

bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=100,
#                   random_state=42)

# %%
y_pred_bag = bagging.predict(X_test)
#Bagging accuracy
print("Bagging Accuracy:", accuracy_score(y_test, y_pred_bag))
# Out:
# Bagging Accuracy: 0.9347826086956522

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier

boost = AdaBoostClassifier(n_estimators=100, random_state=42)
boost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
y_pred_boost = boost.predict(X_test)

print("Boosting Accuracy:", accuracy_score(y_test, y_pred_boost))
# Out:
# Boosting Accuracy: 0.532608695652174

# %% [raw]
# Apply the Bagging and Boosting methods and compare the results
#
# Bagging achieved an accuracy of 93%, performing slightly better than Random Forest, while Boosting achieved 53% accuracy, indicating lower performance. Bagging is more effective for this dataset.

# %% [markdown]
# ### Additional Notes:
# #### 1. Explain Bagging and Boosting methods. How is it different from each other.

# %% [raw]
# Bagging (Bootstrap Aggregation) trains multiple models in parallel on random samples and reduces variance.
# Boosting trains models sequentially, focusing on correcting previous errors and reduces bias.
#
# Difference:
#
# Bagging works in parallel and treats all models equally, while Boosting works sequentially and gives more importance to misclassified data.

# %% [markdown]
# #### 2. Explain how to handle imbalance in the data.

# %% [raw]
# Imbalanced data can be handled using techniques like oversampling (SMOTE), undersampling, or class weighting. In this project, SMOTE is used to balance the dataset by generating synthetic samples.
